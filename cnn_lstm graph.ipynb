# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0,2"

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
data=os.listdir('data/')
data
# Out:
# ['HumanMethylation450-BRCA',
#  'HumanMethylation450-COAD',
#  'HumanMethylation450-KIRC',
#  'HumanMethylation450-KIRP',
#  'HumanMethylation450-LIHC',
#  'HumanMethylation450-LUAD',
#  'HumanMethylation450-LUSC']

# %%
def get_data(data):
    methy_data = pd.read_csv(f'data/{data}', sep='\t')
    sample_name = methy_data.columns
    CG_id = methy_data.iloc[:, 0].tolist()
    df_data = methy_data.iloc[:, 1:]
    df_data.to_csv(f'{data}_feature.csv', index=False)
    return sample_name

def get_label(sample_name,data):
    label_data = pd.DataFrame(index=["label"], columns=sample_name[1:])
    labels = []
    for i in sample_name[1:]:
        if i[-2:] == '11':
            
            labels.append('0')
        else:
            if data=='HumanMethylation450-BRCA':
                labels.append('1')
            elif data=='HumanMethylation450-COAD':
                labels.append('2')
            elif data=='HumanMethylation450-KIRC':
                labels.append('3')
            elif data=='HumanMethylation450-KIRP':
                labels.append('4')
            elif data=='HumanMethylation450-LIHC':
                labels.append('5')
            elif data=='HumanMethylation450-LUAD':
                labels.append('6')
            elif data=='HumanMethylation450-LUSC':
                labels.append('7')
    label_data.loc['label'] = labels
    df_label = label_data
    df_label.to_csv(f'{data}_label.csv', index=False)

# %%
for file in tqdm(data):
    samples_name = get_data(file)
    get_label(samples_name,file)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [12:01<00:00, 103.14s/it]

# %%
df1=pd.read_csv('HumanMethylation450-BRCA_feature.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485577 entries, 0 to 485576
# Columns: 888 entries, TCGA-OL-A66H-01 to TCGA-AR-A0U0-01
# dtypes: float64(888)
# memory usage: 3.2 GB

# %%
df1.head()
# Out:
#    TCGA-OL-A66H-01  TCGA-3C-AALK-01  TCGA-AC-A5EH-01  TCGA-EW-A2FW-01  \
# 0           0.0192           0.2032           0.3003           0.0287
# 1           0.0179           0.2890           0.0892           0.0234
# 2           0.0367           0.0750           0.0333           0.0460
# 3           0.0655           0.1370           0.0770           0.0688
# 4           0.0748           0.1251           0.6269           0.0947
#
#    TCGA-E9-A1R0-01  TCGA-AR-A1AJ-01  TCGA-AC-A62Y-01  TCGA-E9-A1QZ-01  \
# 0           0.0382           0.0426           0.0240           0.2907
# 1           0.0260           0.0310           0.0228           0.0255
# 2           0.0411           0.1116           0.0386           0.0372
# 3           0.0562           0.0472           0.0874           0.0926
# 4           0.1677           0.0670           0.0712           0.2560
#
#    TCGA-E9-A1R2-01  TCGA-E9-A3X8-01  ...  TCGA-BH-A0DI-01  TCGA-E2-A1IG-01  \
# 0           0.0293           0.0300  ...           0.0481           0.0263
# 1           0.0221           0.0258  ...           0.0247           0.0166
# 2           0.0384           0.0423  ...           0.0765           0.0415
# 3           0.0532           0.0570  ...           0.0433           0.0483
# 4           0.0892           0.1996  ...           0.5668           0.0813
#
#    TCGA-E2-A107-01  TCGA-5L-AAT0-01  TCGA-E9-A1NH-01  TCGA-D8-A27E-01  \
# 0           0.5187           0.0757           0.0458           0.0309
# 1           0.0154           0.0420           0.0262           0.0273
# 2           0.0595           0.0664           0.0370           0.0665
# 3           0.0622           0.1302           0.0495           0.0404
# 4           0.1082           0.1422           0.0986           0.1013
#
#    TCGA-AR-A24Q-01  TCGA-BH-A1F0-01  TCGA-E9-A1RB-11  TCGA-AR-A0U0-01
# 0           0.0412           0.0452           0.0492           0.0445
# 1           0.0247           0.0214           0.0247           0.0192
# 2           0.0387           0.0663           0.0425           0.0320
# 3           0.0693           0.0739           0.2753           0.0920
# 4           0.0529           0.1042           0.3801           0.3857
#
# [5 rows x 888 columns]

# %%
df1=pd.read_csv('HumanMethylation450-BRCA_feature.csv')
df2=pd.read_csv('HumanMethylation450-COAD_feature.csv')
df3=pd.read_csv('HumanMethylation450-KIRC_feature.csv')
df4=pd.read_csv('HumanMethylation450-KIRP_feature.csv')
df5=pd.read_csv('HumanMethylation450-LIHC_feature.csv')
df6=pd.read_csv('HumanMethylation450-LUAD_feature.csv')
df7=pd.read_csv('HumanMethylation450-LUSC_feature.csv')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[17], line 5
#       3 df3=pd.read_csv('HumanMethylation450-KIRC_feature.csv')
#       4 df4=pd.read_csv('HumanMethylation450-KIRP_feature.csv')
# ----> 5 df5=pd.read_csv('HumanMethylation450-LIHC_feature.csv')
#       6 df6=pd.read_csv('HumanMethylation450-LUAD_feature.csv')
#       7 df7=pd.read_csv('HumanMethylation450-LUSC_feature.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1765, in TextFileReader.read(self, nrows)
#    1762     else:
#    1763         new_rows = len(index)
# -> 1765     df = DataFrame(col_dict, columns=columns, index=index)
#    1767     self._currow += new_rows
#    1768 return df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:152, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     149 axes = [columns, index]
#     151 if typ == "block":
# --> 152     return create_block_manager_from_column_arrays(
#     153         arrays, axes, consolidate=consolidate, refs=refs
#     154     )
#     155 elif typ == "array":
#     156     return ArrayManager(arrays, [index, columns])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2086, in create_block_manager_from_column_arrays(arrays, axes, consolidate, refs)
#    2068 def create_block_manager_from_column_arrays(
#    2069     arrays: list[ArrayLike],
#    2070     axes: list[Index],
#    (...)
#    2082     # These last three are sufficient to allow us to safely pass
#    2083     #  verify_integrity=False below.
#    2085     try:
# -> 2086         blocks = _form_blocks(arrays, consolidate, refs)
#    2087         mgr = BlockManager(blocks, axes, verify_integrity=False)
#    2088     except ValueError as e:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2160, in _form_blocks(arrays, consolidate, refs)
#    2157 if issubclass(dtype.type, (str, bytes)):
#    2158     dtype = np.dtype(object)
# -> 2160 values, placement = _stack_arrays(list(tup_block), dtype)
#    2161 if is_dtlike:
#    2162     values = ensure_wrapped_if_datetimelike(values)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2200, in _stack_arrays(tuples, dtype)
#    2197 first = arrays[0]
#    2198 shape = (len(arrays),) + first.shape
# -> 2200 stacked = np.empty(shape, dtype=dtype)
#    2201 for i, arr in enumerate(arrays):
#    2202     stacked[i] = arr
#
# MemoryError: Unable to allocate 1.55 GiB for an array with shape (429, 485577) and data type float64

# %%
df_feature=pd.concat([df1,df2,df3,df4,df5,df6,df7],axis=1,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_feature=pd.concat([df1,df2,df3,df4,df5,df6,df7],axis=1,ignore_index=True)
#
# NameError: name 'df6' is not defined

# %%
df_feature=df_feature.dropna(axis=0)

# %%
df1_label=pd.read_csv('HumanMethylation450-BRCA_label.csv')
df2_label=pd.read_csv('HumanMethylation450-COAD_label.csv')
df3_label=pd.read_csv('HumanMethylation450-KIRC_label.csv')
df4_label=pd.read_csv('HumanMethylation450-KIRP_label.csv')
df5_label=pd.read_csv('HumanMethylation450-LIHC_label.csv')
df6_label=pd.read_csv('HumanMethylation450-LUAD_label.csv')
df7_label=pd.read_csv('HumanMethylation450-LUSC_label.csv')

# %%
df_label=pd.concat([df1_label,df2_label,df3_label,df4_label,df5_label,df6_label,df7_label],axis=1,ignore_index=True)

# %%
df_label.T

# %%
X_train=df_feature.T
y_train=df_label.T

# %%
from sklearn.decomposition import PCA
pca_feature = PCA(n_components=100)

# %%
X_train_feature=pca_feature.fit_transform(X_train)

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
y_train=y_train.values

# %%
y_train_features=y_train.flatten()

# %%
X_train_feature.shape

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import cohen_kappa_score
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import seaborn as sns

# %%
import tensorflow as tf

def MODEL(INPUT_SHAPE):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', input_shape=(100,1)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Conv1D(filters=128, kernel_size=3, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.LSTM(128, return_sequences=True),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(8, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
import matplotlib.pyplot as plt
skf = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
accuracys = []
precisions = []
recalls = []
mccs = []
kappas = []
true_label = []
prediction_label = []
fold_history = {}
for fold,(train_index, valid_index) in enumerate(skf.split(X_train_feature, y_train_features),1):
    x_train, y_train = X_train_feature[train_index], y_train_features[train_index]
    x_valid, y_valid = X_train_feature[valid_index], y_train_features[valid_index]

    y_train = tf.keras.utils.to_categorical(y_train)
    y_valid = tf.keras.utils.to_categorical(y_valid)
    x_train=np.expand_dims(x_train,axis=2)
    x_valid=np.expand_dims(x_valid,axis=2)
    INPUT_SHAPE = x_train.shape
    print(INPUT_SHAPE)
    model = MODEL(INPUT_SHAPE)
    checkpoint = ModelCheckpoint(f'best_model_fold_{fold}.h5', monitor="val_accuracy", mode="auto",save_best_only=True, verbose=1)
    early_stop = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1,
                               mode='auto', restore_best_weights=True)

    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=3,
                                  verbose=1, mode='auto')
    callbacks = [checkpoint,early_stop,reduce_lr]
    history=model.fit(x_train, y_train, validation_data=(x_valid, y_valid), epochs=50, batch_size=32, callbacks=callbacks, verbose=1)
    fold_history[f'Fold {fold}'] = history.history 
    y_valid = np.argmax(y_valid, axis=1)
    y_pre = model.predict(x_valid)
    y_pre= np.argmax(y_pre, axis=1)
    accuracy = accuracy_score(y_valid, y_pre)
    accuracys.append(accuracy)
    precision = precision_score(y_valid, y_pre, labels=[0, 1, 2, 3, 4, 5, 6, 7], average='macro')
    precisions.append(precision)
    recall = recall_score(y_valid, y_pre, labels=[0, 1, 2, 3, 4, 5, 6, 7], average='macro')
    recalls.append(recall)
    mcc = matthews_corrcoef(y_valid, y_pre)
    mccs.append(mcc)
    kappa = cohen_kappa_score(y_valid, y_pre, labels=None)
    kappas.append(kappa)
    
    cm = confusion_matrix(y_valid, y_pre)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(8), yticklabels=range(8))
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.title(f"Confusion Matrix - Fold {fold}")
    plt.show()

    print(f"Classification Report - Fold {fold}")
    print(classification_report(y_valid, y_pre, digits=3))

    print(cm)
    print("accuracy = ", accuracy)
    print("precision = ", precision)
    print("recall = ", recall)
    print("mcc = ", mcc)
    print("kappa = ", kappa)
print("The average of accuracy = {:.3%} -std: {:.3f} ".format(np.mean(accuracys), np.std(accuracys)))
print("The average of precision = {:.3%} -std: {:.3f} ".format(np.mean(precisions), np.std(precisions)))
print("The average of recall = {:.3%} -std: {:.3f} ".format(np.mean(recalls), np.std(recalls)))
print("The average of mcc = {:.3%} -std: {:.3f} ".format(np.mean(mccs), np.std(mccs)))
print("The average of kappa = {:.3%} -std: {:.3f} ".format(np.mean(kappas), np.std(kappas)))
# Out:
# Epoch 00008: val_accuracy did not improve from 0.94354
# Epoch 9/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0569 - accuracy: 0.9799 - val_loss: 0.2642 - val_accuracy: 0.9435
#
# Epoch 00009: val_accuracy did not improve from 0.94354
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0402 - accuracy: 0.9888 - val_loss: 0.2347 - val_accuracy: 0.9480
#
# Epoch 00010: val_accuracy improved from 0.94354 to 0.94799, saving model to best_model_fold_2.h5
# Epoch 11/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0225 - accuracy: 0.9933 - val_loss: 0.2216 - val_accuracy: 0.9525
#
# Epoch 00011: val_accuracy improved from 0.94799 to 0.95245, saving model to best_model_fold_2.h5
# Epoch 12/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0139 - accuracy: 0.9967 - val_loss: 0.2252 - val_accuracy: 0.9539
#
# Epoch 00012: val_accuracy improved from 0.95245 to 0.95394, saving model to best_model_fold_2.h5
# Epoch 13/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.2191 - val_accuracy: 0.9569
#
# Epoch 00013: val_accuracy improved from 0.95394 to 0.95691, saving model to best_model_fold_2.h5
# Epoch 14/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.2051 - val_accuracy: 0.9584
#
# Epoch 00014: val_accuracy improved from 0.95691 to 0.95840, saving model to best_model_fold_2.h5
# Epoch 15/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0070 - accuracy: 0.9993 - val_loss: 0.2112 - val_accuracy: 0.9584
#
# Epoch 00015: val_accuracy did not improve from 0.95840
# Epoch 16/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0117 - accuracy: 0.9974 - val_loss: 0.2157 - val_accuracy: 0.9599
#
# Epoch 00016: val_accuracy improved from 0.95840 to 0.95988, saving model to best_model_fold_2.h5
# Epoch 17/50
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0065 - accuracy: 0.9993 - val_loss: 0.2158 - val_accuracy: 0.9584
#
# Epoch 00017: val_accuracy did not improve from 0.95988
# Epoch 18/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0056 - accuracy: 0.9993 - val_loss: 0.2191 - val_accuracy: 0.9569
#
# Epoch 00018: val_accuracy did not improve from 0.95988
# Epoch 19/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0080 - accuracy: 0.9985 - val_loss: 0.2191 - val_accuracy: 0.9569
#
# Epoch 00019: val_accuracy did not improve from 0.95988
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 20/50
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0054 - accuracy: 0.9993 - val_loss: 0.2208 - val_accuracy: 0.9569
#
# Epoch 00020: val_accuracy did not improve from 0.95988
# Epoch 21/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.2207 - val_accuracy: 0.9569
#
# Epoch 00021: val_accuracy did not improve from 0.95988
# Epoch 22/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.2203 - val_accuracy: 0.9569
#
# Epoch 00022: val_accuracy did not improve from 0.95988
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 23/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.2182 - val_accuracy: 0.9569
#
# Epoch 00023: val_accuracy did not improve from 0.95988
# Epoch 24/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.2194 - val_accuracy: 0.9569
#
# Epoch 00024: val_accuracy did not improve from 0.95988
# Epoch 25/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.2193 - val_accuracy: 0.9569
#
# Epoch 00025: val_accuracy did not improve from 0.95988
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 26/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.2198 - val_accuracy: 0.9569
#
# Epoch 00026: val_accuracy did not improve from 0.95988
# Restoring model weights from the end of the best epoch.
# Epoch 00026: early stopping
# [[182   4   0   1   0   0   0   0]
#  [  5 311   0   0   0   0   0   0]
#  [  1   0 116   0   0   0   2   0]
#  [  0   2   0 116   5   2   1   2]
#  [  1   1   0   6 103   0   0   0]
#  [  2   1   0   0   0 148   0   0]
#  [  1   0   0   0   2   1 179   1]
#  [  1   2   0   1   1   0   2 143]]
# accuracy =  0.9598811292719168
# precision =  0.9590370060581459
# recall =  0.9532309959342666
# mcc =  0.9532837550768217
# kappa =  0.9531969586136554
# (2690, 100, 1)
# Epoch 1/50
# 85/85 [==============================] - 8s 39ms/step - loss: 1.1948 - accuracy: 0.5851 - val_loss: 1.5457 - val_accuracy: 0.6592
#
# Epoch 00001: val_accuracy improved from -inf to 0.65923, saving model to best_model_fold_3.h5
# Epoch 2/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.3059 - accuracy: 0.9093 - val_loss: 0.6133 - val_accuracy: 0.8348
#
# Epoch 00002: val_accuracy improved from 0.65923 to 0.83482, saving model to best_model_fold_3.h5
# Epoch 3/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.2145 - accuracy: 0.9338 - val_loss: 0.2780 - val_accuracy: 0.9137
#
# Epoch 00003: val_accuracy improved from 0.83482 to 0.91369, saving model to best_model_fold_3.h5
# Epoch 4/50
# 85/85 [==============================] - 2s 22ms/step - loss: 0.1336 - accuracy: 0.9572 - val_loss: 0.2130 - val_accuracy: 0.9420
#
# Epoch 00004: val_accuracy improved from 0.91369 to 0.94196, saving model to best_model_fold_3.h5
# Epoch 5/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.1447 - accuracy: 0.9524 - val_loss: 0.2084 - val_accuracy: 0.9494
#
# Epoch 00005: val_accuracy improved from 0.94196 to 0.94940, saving model to best_model_fold_3.h5
# Epoch 6/50
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0798 - accuracy: 0.9740 - val_loss: 0.2144 - val_accuracy: 0.9479
#
# Epoch 00006: val_accuracy did not improve from 0.94940
# Epoch 7/50
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0981 - accuracy: 0.9699 - val_loss: 0.2384 - val_accuracy: 0.9405
#
# Epoch 00007: val_accuracy did not improve from 0.94940
# Epoch 8/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0830 - accuracy: 0.9740 - val_loss: 0.2403 - val_accuracy: 0.9345
#
# Epoch 00008: val_accuracy did not improve from 0.94940
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 9/50
# 85/85 [==============================] - 2s 28ms/step - loss: 0.0545 - accuracy: 0.9825 - val_loss: 0.1848 - val_accuracy: 0.9568
#
# Epoch 00009: val_accuracy improved from 0.94940 to 0.95685, saving model to best_model_fold_3.h5
# Epoch 10/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0323 - accuracy: 0.9922 - val_loss: 0.1804 - val_accuracy: 0.9598
#
# Epoch 00010: val_accuracy improved from 0.95685 to 0.95982, saving model to best_model_fold_3.h5
# Epoch 11/50
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0244 - accuracy: 0.9933 - val_loss: 0.1803 - val_accuracy: 0.9583
#
# Epoch 00011: val_accuracy did not improve from 0.95982
# Epoch 12/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0284 - accuracy: 0.9903 - val_loss: 0.1813 - val_accuracy: 0.9613
#
# Epoch 00012: val_accuracy improved from 0.95982 to 0.96131, saving model to best_model_fold_3.h5
# Epoch 13/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0176 - accuracy: 0.9970 - val_loss: 0.1830 - val_accuracy: 0.9613
#
# Epoch 00013: val_accuracy did not improve from 0.96131
# Epoch 14/50
# 85/85 [==============================] - 2s 28ms/step - loss: 0.0184 - accuracy: 0.9959 - val_loss: 0.1845 - val_accuracy: 0.9628
#
# Epoch 00014: val_accuracy improved from 0.96131 to 0.96280, saving model to best_model_fold_3.h5
# Epoch 15/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0206 - accuracy: 0.9929 - val_loss: 0.1868 - val_accuracy: 0.9688
#
# Epoch 00015: val_accuracy improved from 0.96280 to 0.96875, saving model to best_model_fold_3.h5
# Epoch 16/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0206 - accuracy: 0.9937 - val_loss: 0.1877 - val_accuracy: 0.9628
#
# Epoch 00016: val_accuracy did not improve from 0.96875
# Epoch 17/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0129 - accuracy: 0.9974 - val_loss: 0.1870 - val_accuracy: 0.9613
#
# Epoch 00017: val_accuracy did not improve from 0.96875
# Epoch 18/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0146 - accuracy: 0.9974 - val_loss: 0.1852 - val_accuracy: 0.9673
#
# Epoch 00018: val_accuracy did not improve from 0.96875
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 19/50
# 85/85 [==============================] - 2s 27ms/step - loss: 0.0143 - accuracy: 0.9959 - val_loss: 0.1860 - val_accuracy: 0.9658
#
# Epoch 00019: val_accuracy did not improve from 0.96875
# Epoch 20/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0187 - accuracy: 0.9955 - val_loss: 0.1860 - val_accuracy: 0.9658
#
# Epoch 00020: val_accuracy did not improve from 0.96875
# Epoch 21/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0148 - accuracy: 0.9959 - val_loss: 0.1842 - val_accuracy: 0.9658
#
# Epoch 00021: val_accuracy did not improve from 0.96875
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 22/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0119 - accuracy: 0.9978 - val_loss: 0.1831 - val_accuracy: 0.9658
#
# Epoch 00022: val_accuracy did not improve from 0.96875
# Epoch 23/50
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0131 - accuracy: 0.9978 - val_loss: 0.1855 - val_accuracy: 0.9658
#
# Epoch 00023: val_accuracy did not improve from 0.96875
# Epoch 24/50
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0114 - accuracy: 0.9974 - val_loss: 0.1852 - val_accuracy: 0.9658
#
# Epoch 00024: val_accuracy did not improve from 0.96875
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 25/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0107 - accuracy: 0.9981 - val_loss: 0.1861 - val_accuracy: 0.9658
#
# Epoch 00025: val_accuracy did not improve from 0.96875
# Restoring model weights from the end of the best epoch.
# Epoch 00025: early stopping
# [[274   5   0   1   0   0   0   0]
#  [  7 466   0   0   0   0   1   0]
#  [  2   0 175   0   0   0   2   0]
#  [  0   3   0 177   6   2   1   3]
#  [  1   1   0   9 153   1   0   1]
#  [  2   2   0   0   1 221   1   0]
#  [  1   1   0   0   2   1 269   2]
#  [  1   3   0   1   1   0   4 214]]
# accuracy =  0.96875
# precision =  0.9694034085783281
# recall =  0.9642569821617748
# mcc =  0.9635887550241337
# kappa =  0.963556072051133
# (2690, 100, 1)
# Epoch 1/50
# 85/85 [==============================] - 8s 38ms/step - loss: 1.1856 - accuracy: 0.6175 - val_loss: 1.4859 - val_accuracy: 0.6726
#
# Epoch 00001: val_accuracy improved from -inf to 0.67262, saving model to best_model_fold_4.h5
# Epoch 2/50
# 85/85 [==============================] - 2s 22ms/step - loss: 0.3155 - accuracy: 0.9115 - val_loss: 0.5787 - val_accuracy: 0.8646
#
# Epoch 00002: val_accuracy improved from 0.67262 to 0.86458, saving model to best_model_fold_4.h5
# Epoch 3/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.1876 - accuracy: 0.9409 - val_loss: 0.2614 - val_accuracy: 0.9360
#
# Epoch 00003: val_accuracy improved from 0.86458 to 0.93601, saving model to best_model_fold_4.h5
# Epoch 4/50
# 85/85 [==============================] - 2s 21ms/step - loss: 0.1561 - accuracy: 0.9513 - val_loss: 0.2556 - val_accuracy: 0.9286
#
# Epoch 00004: val_accuracy did not improve from 0.93601
# Epoch 5/50
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0899 - accuracy: 0.9717 - val_loss: 0.2125 - val_accuracy: 0.9539
#
# Epoch 00005: val_accuracy improved from 0.93601 to 0.95387, saving model to best_model_fold_4.h5
# Epoch 6/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0789 - accuracy: 0.9762 - val_loss: 0.1966 - val_accuracy: 0.9524
#
# Epoch 00006: val_accuracy did not improve from 0.95387
# Epoch 7/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0576 - accuracy: 0.9825 - val_loss: 0.2398 - val_accuracy: 0.9524
#
# Epoch 00007: val_accuracy did not improve from 0.95387
# Epoch 8/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.1316 - accuracy: 0.9599 - val_loss: 0.2889 - val_accuracy: 0.9256
#
# Epoch 00008: val_accuracy did not improve from 0.95387
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 9/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0630 - accuracy: 0.9792 - val_loss: 0.1986 - val_accuracy: 0.9613
#
# Epoch 00009: val_accuracy improved from 0.95387 to 0.96131, saving model to best_model_fold_4.h5
# Epoch 10/50
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0483 - accuracy: 0.9870 - val_loss: 0.1744 - val_accuracy: 0.9643
#
# Epoch 00010: val_accuracy improved from 0.96131 to 0.96429, saving model to best_model_fold_4.h5
# Epoch 11/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0377 - accuracy: 0.9888 - val_loss: 0.1743 - val_accuracy: 0.9628
#
# Epoch 00011: val_accuracy did not improve from 0.96429
# Epoch 12/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 0.1804 - val_accuracy: 0.9643
#
# Epoch 00012: val_accuracy did not improve from 0.96429
# Epoch 13/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0324 - accuracy: 0.9911 - val_loss: 0.1769 - val_accuracy: 0.9643
#
# Epoch 00013: val_accuracy did not improve from 0.96429
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 14/50
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0245 - accuracy: 0.9926 - val_loss: 0.1785 - val_accuracy: 0.9628
#
# Epoch 00014: val_accuracy did not improve from 0.96429
# Epoch 15/50
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0281 - accuracy: 0.9903 - val_loss: 0.1793 - val_accuracy: 0.9628
#
# Epoch 00015: val_accuracy did not improve from 0.96429
# Epoch 16/50
# 85/85 [==============================] - 2s 27ms/step - loss: 0.0229 - accuracy: 0.9944 - val_loss: 0.1800 - val_accuracy: 0.9628
#
# Epoch 00016: val_accuracy did not improve from 0.96429
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 17/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0214 - accuracy: 0.9948 - val_loss: 0.1801 - val_accuracy: 0.9643
#
# Epoch 00017: val_accuracy did not improve from 0.96429
# Epoch 18/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0243 - accuracy: 0.9944 - val_loss: 0.1811 - val_accuracy: 0.9658
#
# Epoch 00018: val_accuracy improved from 0.96429 to 0.96577, saving model to best_model_fold_4.h5
# Epoch 19/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0258 - accuracy: 0.9937 - val_loss: 0.1816 - val_accuracy: 0.9658
#
# Epoch 00019: val_accuracy did not improve from 0.96577
# Epoch 20/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0252 - accuracy: 0.9926 - val_loss: 0.1817 - val_accuracy: 0.9658
#
# Epoch 00020: val_accuracy did not improve from 0.96577
# Epoch 21/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0233 - accuracy: 0.9926 - val_loss: 0.1804 - val_accuracy: 0.9643
#
# Epoch 00021: val_accuracy did not improve from 0.96577
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 22/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0206 - accuracy: 0.9959 - val_loss: 0.1809 - val_accuracy: 0.9658
#
# Epoch 00022: val_accuracy did not improve from 0.96577
# Epoch 23/50
# 85/85 [==============================] - 2s 27ms/step - loss: 0.0231 - accuracy: 0.9922 - val_loss: 0.1819 - val_accuracy: 0.9658
#
# Epoch 00023: val_accuracy did not improve from 0.96577
# Epoch 24/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0268 - accuracy: 0.9941 - val_loss: 0.1806 - val_accuracy: 0.9658
#
# Epoch 00024: val_accuracy did not improve from 0.96577
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 25/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0274 - accuracy: 0.9922 - val_loss: 0.1810 - val_accuracy: 0.9658
#
# Epoch 00025: val_accuracy did not improve from 0.96577
# Epoch 26/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0257 - accuracy: 0.9926 - val_loss: 0.1799 - val_accuracy: 0.9643
#
# Epoch 00026: val_accuracy did not improve from 0.96577
# Epoch 27/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0262 - accuracy: 0.9929 - val_loss: 0.1804 - val_accuracy: 0.9658
#
# Epoch 00027: val_accuracy did not improve from 0.96577
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 28/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0244 - accuracy: 0.9926 - val_loss: 0.1813 - val_accuracy: 0.9658
#
# Epoch 00028: val_accuracy did not improve from 0.96577
# Restoring model weights from the end of the best epoch.
# Epoch 00028: early stopping
# [[366   5   0   1   0   0   0   1]
#  [  7 621   0   0   0   0   1   3]
#  [  2   0 235   0   0   0   2   0]
#  [  0   4   0 236  10   2   1   3]
#  [  1   1   0  11 206   1   0   1]
#  [  3   2   0   1   1 293   1   2]
#  [  2   1   0   1   2   1 355   6]
#  [  1   3   0   1   1   0   6 286]]
# accuracy =  0.9657738095238095
# precision =  0.96174589418963
# recall =  0.9638619170516782
# mcc =  0.9602748544977621
# kappa =  0.9601434793484119
# (2690, 100, 1)
# Epoch 1/50
# 85/85 [==============================] - 9s 42ms/step - loss: 1.1923 - accuracy: 0.5829 - val_loss: 1.4715 - val_accuracy: 0.8348
#
# Epoch 00001: val_accuracy improved from -inf to 0.83482, saving model to best_model_fold_5.h5
# Epoch 2/50
# 85/85 [==============================] - 2s 27ms/step - loss: 0.2771 - accuracy: 0.9138 - val_loss: 0.5965 - val_accuracy: 0.8482
#
# Epoch 00002: val_accuracy improved from 0.83482 to 0.84821, saving model to best_model_fold_5.h5
# Epoch 3/50
# 85/85 [==============================] - 2s 26ms/step - loss: 0.2393 - accuracy: 0.9245 - val_loss: 0.2254 - val_accuracy: 0.9345
#
# Epoch 00003: val_accuracy improved from 0.84821 to 0.93452, saving model to best_model_fold_5.h5
# Epoch 4/50
# 85/85 [==============================] - 2s 28ms/step - loss: 0.1161 - accuracy: 0.9680 - val_loss: 0.1262 - val_accuracy: 0.9628
#
# Epoch 00004: val_accuracy improved from 0.93452 to 0.96280, saving model to best_model_fold_5.h5
# Epoch 5/50
# 85/85 [==============================] - 2s 28ms/step - loss: 0.0947 - accuracy: 0.9706 - val_loss: 0.2023 - val_accuracy: 0.9330
#
# Epoch 00005: val_accuracy did not improve from 0.96280
# Epoch 6/50
# 85/85 [==============================] - 2s 27ms/step - loss: 0.1533 - accuracy: 0.9532 - val_loss: 0.1376 - val_accuracy: 0.9524
#
# Epoch 00006: val_accuracy did not improve from 0.96280
# Epoch 7/50
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0893 - accuracy: 0.9725 - val_loss: 0.0901 - val_accuracy: 0.9658
#
# Epoch 00007: val_accuracy improved from 0.96280 to 0.96577, saving model to best_model_fold_5.h5
# Epoch 8/50
# 85/85 [==============================] - 2s 27ms/step - loss: 0.1085 - accuracy: 0.9643 - val_loss: 0.1066 - val_accuracy: 0.9613
#
# Epoch 00008: val_accuracy did not improve from 0.96577
# Epoch 9/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0642 - accuracy: 0.9799 - val_loss: 0.0961 - val_accuracy: 0.9688
#
# Epoch 00009: val_accuracy improved from 0.96577 to 0.96875, saving model to best_model_fold_5.h5
# Epoch 10/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.1055 - accuracy: 0.9680 - val_loss: 0.1193 - val_accuracy: 0.9554
#
# Epoch 00010: val_accuracy did not improve from 0.96875
# Epoch 11/50
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0800 - accuracy: 0.9740 - val_loss: 0.0967 - val_accuracy: 0.9673
#
# Epoch 00011: val_accuracy did not improve from 0.96875
# Epoch 12/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.1135 - accuracy: 0.9658 - val_loss: 0.1828 - val_accuracy: 0.9435
#
# Epoch 00012: val_accuracy did not improve from 0.96875
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0544 - accuracy: 0.9829 - val_loss: 0.1222 - val_accuracy: 0.9643
#
# Epoch 00013: val_accuracy did not improve from 0.96875
# Epoch 14/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0333 - accuracy: 0.9907 - val_loss: 0.1234 - val_accuracy: 0.9628
#
# Epoch 00014: val_accuracy did not improve from 0.96875
# Epoch 15/50
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0419 - accuracy: 0.9877 - val_loss: 0.1190 - val_accuracy: 0.9643
#
# Epoch 00015: val_accuracy did not improve from 0.96875
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 16/50
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0274 - accuracy: 0.9933 - val_loss: 0.1168 - val_accuracy: 0.9643
#
# Epoch 00016: val_accuracy did not improve from 0.96875
# Epoch 17/50
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0320 - accuracy: 0.9888 - val_loss: 0.1160 - val_accuracy: 0.9658
#
# Epoch 00017: val_accuracy did not improve from 0.96875
# Epoch 18/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0262 - accuracy: 0.9918 - val_loss: 0.1165 - val_accuracy: 0.9658
#
# Epoch 00018: val_accuracy did not improve from 0.96875
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 19/50
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0320 - accuracy: 0.9903 - val_loss: 0.1165 - val_accuracy: 0.9658
#
# Epoch 00019: val_accuracy did not improve from 0.96875
# Restoring model weights from the end of the best epoch.
# Epoch 00019: early stopping
# [[452   6   0   1   0   4   1   2]
#  [  7 776   0   1   0   0   1   5]
#  [  2   0 295   0   0   0   2   0]
#  [  0   4   0 300  10   2   1   3]
#  [  1   1   0  14 258   1   0   1]
#  [  3   3   0   1   1 368   1   2]
#  [  2   2   1   1   2   1 443   8]
#  [  1   5   0   1   1   0   7 357]]
# accuracy =  0.96875
# precision =  0.9693610525833058
# recall =  0.9692527112913931
# mcc =  0.9637037558256264
# kappa =  0.96358437885458
# The average of accuracy = 96.639% -std: 0.003
# The average of precision = 96.551% -std: 0.004
# The average of recall = 96.310% -std: 0.005
# The average of mcc = 96.090% -std: 0.004
# The average of kappa = 96.082% -std: 0.004

# %%
plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
for fold, history in fold_history.items():
    plt.plot(history['accuracy'], label=f'{fold} Train')
    plt.plot(history['val_accuracy'], linestyle='dashed', label=f'{fold} Val')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot Loss
plt.subplot(1, 2, 2)
for fold, history in fold_history.items():
    plt.plot(history['loss'], label=f'{fold} Train')
    plt.plot(history['val_loss'], linestyle='dashed', label=f'{fold} Val')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
